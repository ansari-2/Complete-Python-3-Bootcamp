# %% [markdown]
# <a href="https://colab.research.google.com/github/ansari-2/Complete-Python-3-Bootcamp/blob/master/Number_Guessing_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
from IPython.display import clear_output 
def randomnum():
 clear_output()
 print("""Rules of the game --> 
 You will be given seven chances to guess
 a random number generated by the computer between
 1 to 100 and you can win only if you guess the correct number

 Instructions --> 
 You cannot enter any other values except numbers
 from 1 to 100 and you cannot enter other word than
 yes or no in  replay box
                     """)

 global random_num 
 random_num = randint(1,100)

def start():
  global guess
  guess = int(input("Guess the number: "))
 
def guessing():
  hint = 0
  chances = 0
  randomnum()
  while chances <  7:
    start()
    hint = abs(guess-random_num)
    if hint == 0:
      print("You won the game!!",'\U0001F60A')
      break
    elif hint <=  10:
      print("You are close!!")
    else:
      print("You are too far!!")  
    chances +=1
  if chances == 7 :
    print('You lost the game',"\U0001F614")
  
def replay():
  replay=input('Do you wanna play again?[yes/no]:').lower()
  if replay == 'yes':
    print('\n')
    guessing()


guessing()   
replay()
# Out:
# Rules of the game -->
#  You will be given seven chances to guess
#  a random number generated by the computer between
#  1 to 100 and you can win only if you guess the correct number
#
#  Instructions -->
#  You cannot enter any other values except numbers
#  from 1 to 100 and you cannot enter other word than
#  yes or no in  replay box
#
# Guess the number: 55
# You are too far!!
# Guess the number: 45
# You are too far!!
# Guess the number: 35
# You are too far!!
# Guess the number: 25
# You are close!!
# Guess the number: 15
# You are close!!
# Guess the number: 17
# You are close!!
# Guess the number: 18
# You are close!!
# You lost the game 😔
# Do you wanna play again?[yes/no]:no
